# %% [markdown]
# # Sleep Efficiency Dataset
#
# ## Day 1: EDA and Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the data base
sleep_df = pd.read_csv('Sleep_Efficiency.csv')

# %%
# Checking general info: data types, number of columns.
sleep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %%
# Eliminating duplicates
sleep_df = sleep_df.drop_duplicates()
sleep_df.info()
# No row was droppped, therefore there are no duplicates
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %%
# Changing title of columns
sleep_df.rename(columns={'Wakeup time':'wakeup_time','Sleep Duration':'sleep_duration',
                          'Sleep efficiency':'sleep_efficiency','REM sleep percentage':'rem_sleep_percentage', 
                          'Deep sleep percentage':'deep_sleep_percentage','Light sleep percentage': 'light_sleep_percentage',
                          'Caffeine consumption':'caffeine_consumption','Alcohol consumption':'alcohol_consumption',
                         'Smoking status':'smoking_status','Exercise frequency':'exercise_frequency'}, inplace=True )
sleep_df
# Out:
#       ID  Age  Gender              Bedtime          wakeup_time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
# Making all columns to be in lower case
sleep_df = sleep_df.rename(columns= lambda x: x.lower())
sleep_df
# Out:
#       id  age  gender              bedtime          wakeup_time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
# Finding null entries in all columns
sleep_df.isnull().sum()
# Out:
# id                         0
# age                        0
# gender                     0
# bedtime                    0
# wakeup_time                0
# sleep duration             0
# sleep_efficiency           0
# rem_sleep_percentage       0
# deep_sleep_percentage      0
# light_sleep_percentage     0
# awakenings                20
# caffeine_consumption      25
# alcohol_consumption       14
# smoking_status             0
# exercise_frequency         6
# dtype: int64

# %%
# Creating a function that finds the mean of a column, leaving out the null values
def mean_nonzero(column_name):
    mean_list_nonzero = []
    for i in sleep_df[column_name]:
        if i is not None and not pd.isna(i):
            mean_list_nonzero.append(i)
    if len(mean_list_nonzero) > 0:
        mean = sum(mean_list_nonzero) / len(mean_list_nonzero)
        rounded_mean = round(mean, 2) 
        return rounded_mean
    else:
        return None

# %%
# Appliying the function to find the mean in the columns where are null values
mean_awakenings = mean_nonzero('awakenings')
mean_caffeine_consumption = mean_nonzero('caffeine_consumption')
mean_alcohol_consumption = mean_nonzero('alcohol_consumption')
mean_exercise_frequency = mean_nonzero('exercise_frequency')
print ('mean_awakenings: ', mean_awakenings, \
      'mean_caffeine_consumption: ', mean_caffeine_consumption, \
      'mean_alcohol_consumption: ', mean_alcohol_consumption, \
      'mean_exercise_frequency: ', mean_exercise_frequency)
# Out:
# mean_awakenings:  1.64 mean_caffeine_consumption:  23.65 mean_alcohol_consumption:  1.17 mean_exercise_frequency:  1.79

# %%
# Using a lambda function to replace the null values for the mean
sleep_df['awakenings'] = \
sleep_df['awakenings'].apply(lambda x: mean_awakenings if x is None or pd.isna(x) else x)

# %%
sleep_df['caffeine_consumption'] = \
sleep_df['caffeine_consumption'].apply(lambda x: mean_alcohol_consumption if x is None or pd.isna(x) else x)

# %%
sleep_df['alcohol_consumption'] = \
sleep_df['alcohol_consumption'].apply(lambda x: mean_alcohol_consumption if x is None or pd.isna(x) else x)

# %%
sleep_df['exercise_frequency'] = \
sleep_df['exercise_frequency'].apply(lambda x: mean_exercise_frequency if x is None or pd.isna(x) else x)

# %%
# checking that all null values where replaced and there are not any more null values
sleep_df.isnull().sum()
# Out:
# id                        0
# age                       0
# gender                    0
# bedtime                   0
# wakeup_time               0
# sleep duration            0
# sleep_efficiency          0
# rem_sleep_percentage      0
# deep_sleep_percentage     0
# light_sleep_percentage    0
# awakenings                0
# caffeine_consumption      0
# alcohol_consumption       0
# smoking_status            0
# exercise_frequency        0
# dtype: int64

# %%
# To do:
 # bins para wake up and bed time
 # change integers to floats

# %%
# Split the 'bedtime' column into date and time columns
sleep_df[['bedtime_date', 'bedtime_time']] = sleep_df['bedtime'].str.split(' ', 1, expand=True)
sleep_df[['wakeup_date', 'wakeuptime_time']] = sleep_df['wakeup_time'].str.split(' ', 1, expand=True)
sleep_df
# Out:
#       id  age  gender              bedtime          wakeup_time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
sleep_df = sleep_df.drop(columns=["bedtime","wakeup_time"])
sleep_df
# Out:
#       id  age  gender  sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
# Extracting the month of the date columns
# Convert the column to datetime if it's not already in datetime format
sleep_df['bedtime_date'] = pd.to_datetime(sleep_df['bedtime_date'])
# Extract only the month from the datetime column
sleep_df['month'] = sleep_df['bedtime_date'].dt.month
sleep_df = sleep_df.drop(columns=["bedtime_date","wakeup_date"])
sleep_df
# Out:
#       id  age  gender  sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
# checking the Dtype of the month columns
sleep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 451
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      452 non-null    int64
#  1   age                     452 non-null    int64
#  2   gender                  452 non-null    object
#  3   sleep duration          452 non-null    float64
#  4   sleep_efficiency        452 non-null    float64
#  5   rem_sleep_percentage    452 non-null    int64
#  6   deep_sleep_percentage   452 non-null    int64
#  7   light_sleep_percentage  452 non-null    int64
#  8   awakenings              452 non-null    float64
#  9   caffeine_consumption    452 non-null    float64
#  10  alcohol_consumption     452 non-null    float64
#  11  smoking_status          452 non-null    object
#  12  exercise_frequency      452 non-null    float64
#  13  bedtime_time            452 non-null    object
# ...

# %%
# Converting the hour into hours - integers for bedtime_time

# Convert the time column to datetime data type
sleep_df['bedtime_time'] = pd.to_datetime(sleep_df['bedtime_time'], format='%H:%M:%S')

# Extract the hour, minute, and second components
sleep_df['hour'] = sleep_df['bedtime_time'].dt.hour
sleep_df['minute'] = sleep_df['bedtime_time'].dt.minute
sleep_df['second'] = sleep_df['bedtime_time'].dt.second

# Convert the time to hours as a float
sleep_df['bedtime_hours_float'] = (sleep_df['hour'] + sleep_df['minute'] / 60 + sleep_df['second'] / 3600).round(2)

sleep_df = sleep_df.drop(columns= ['hour','minute','second','bedtime_time'])
sleep_df
# Out:
#       id  age  gender  sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
# Converting the hour into hours - integers for wakeuptime_time

# Convert the time column to datetime data type
sleep_df['wakeuptime_time'] = pd.to_datetime(sleep_df['wakeuptime_time'], format='%H:%M:%S')

# Extract the hour, minute, and second components
sleep_df['hour'] = sleep_df['wakeuptime_time'].dt.hour
sleep_df['minute'] = sleep_df['wakeuptime_time'].dt.minute
sleep_df['second'] = sleep_df['wakeuptime_time'].dt.second

# Convert the time to hours as a float
sleep_df['wakeuptime_hours_float'] = (sleep_df['hour'] + sleep_df['minute'] / 60 + sleep_df['second'] / 3600).round(2)

sleep_df = sleep_df.drop(columns= ['hour','minute','second','wakeuptime_time'])
sleep_df
# Out:
#       id  age  gender  sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
# checking the Dtype of the month columns
sleep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 451
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      452 non-null    int64
#  1   age                     452 non-null    int64
#  2   gender                  452 non-null    object
#  3   sleep duration          452 non-null    float64
#  4   sleep_efficiency        452 non-null    float64
#  5   rem_sleep_percentage    452 non-null    int64
#  6   deep_sleep_percentage   452 non-null    int64
#  7   light_sleep_percentage  452 non-null    int64
#  8   awakenings              452 non-null    float64
#  9   caffeine_consumption    452 non-null    float64
#  10  alcohol_consumption     452 non-null    float64
#  11  smoking_status          452 non-null    object
#  12  exercise_frequency      452 non-null    float64
#  13  month                   452 non-null    int64
# ...

# %%
 # verify uniques in dummies for gender
sleep_df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
 # verify uniques in dummies for smoking_status
sleep_df['smoking_status'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# change gender and smoking_status to dummies
sleep_df = pd.get_dummies(sleep_df, columns = ['gender','smoking_status'], drop_first=True)
sleep_df
# Out:
#       id  age  sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0      1   65             6.0              0.88                    18
# 1      2   69             7.0              0.66                    19
# 2      3   40             8.0              0.89                    20
# 3      4   40             6.0              0.51                    23
# 4      5   57             8.0              0.76                    27
# ..   ...  ...             ...               ...                   ...
# 447  448   27             7.5              0.91                    22
# 448  449   52             6.0              0.74                    28
# 449  450   40             8.5              0.55                    20
# 450  451   45             7.0              0.76                    18
# 451  452   18             7.5              0.63                    22
#
#      deep_sleep_percentage  light_sleep_percentage  awakenings  \
# ...

# %%
# removing id column, as we don't need it as a variable for our model
sleep_df = sleep_df.drop(columns= ['id'])
sleep_df
# Out:
#      age  sleep duration  sleep_efficiency  rem_sleep_percentage  \
# 0     65             6.0              0.88                    18
# 1     69             7.0              0.66                    19
# 2     40             8.0              0.89                    20
# 3     40             6.0              0.51                    23
# 4     57             8.0              0.76                    27
# ..   ...             ...               ...                   ...
# 447   27             7.5              0.91                    22
# 448   52             6.0              0.74                    28
# 449   40             8.5              0.55                    20
# 450   45             7.0              0.76                    18
# 451   18             7.5              0.63                    22
#
#      deep_sleep_percentage  light_sleep_percentage  awakenings  \
# 0                       70                      12         0.0
# ...

# %%
# checking the Dtype of the month columns
sleep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     452 non-null    int64
#  1   sleep duration          452 non-null    float64
#  2   sleep_efficiency        452 non-null    float64
#  3   rem_sleep_percentage    452 non-null    int64
#  4   deep_sleep_percentage   452 non-null    int64
#  5   light_sleep_percentage  452 non-null    int64
#  6   awakenings              452 non-null    float64
#  7   caffeine_consumption    452 non-null    float64
#  8   alcohol_consumption     452 non-null    float64
#  9   exercise_frequency      452 non-null    float64
#  10  month                   452 non-null    int64
#  11  bedtime_hours_float     452 non-null    float64
#  12  wakeuptime_hours_float  452 non-null    float64
#  13  gender_Male             452 non-null    uint8
# ...

# %% [markdown]
# ### Checking the distribution of the variables and it's correlation

# %%
sleep_df.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sleep duration'}>,
#         <AxesSubplot:title={'center':'sleep_efficiency'}>,
#         <AxesSubplot:title={'center':'rem_sleep_percentage'}>],
#        [<AxesSubplot:title={'center':'deep_sleep_percentage'}>,
#         <AxesSubplot:title={'center':'light_sleep_percentage'}>,
#         <AxesSubplot:title={'center':'awakenings'}>,
#         <AxesSubplot:title={'center':'caffeine_consumption'}>],
#        [<AxesSubplot:title={'center':'alcohol_consumption'}>,
#         <AxesSubplot:title={'center':'exercise_frequency'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'bedtime_hours_float'}>],
#        [<AxesSubplot:title={'center':'wakeuptime_hours_float'}>,
#         <AxesSubplot:title={'center':'gender_Male'}>,
#         <AxesSubplot:title={'center':'smoking_status_Yes'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
corr = sleep_df.corr()
fig2 = plt.figure(figsize=(15,5))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, annot=True, mask=mask)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Developing the predictive model without any transformation

# %%
RAND_STATE = 34 # for reproducible shuffling
TT_RATIO = 0.3 # test/train

# %%
y = sleep_df.sleep_efficiency
X = sleep_df.drop('sleep_efficiency', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TT_RATIO, random_state=RAND_STATE)
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
X_train.head()
# Out:
#      age  sleep duration  rem_sleep_percentage  deep_sleep_percentage  \
# 229   26             7.0                    24                     56
# 363   30            10.0                    22                     65
# 215   22             7.0                    28                     60
# 211   10             7.0                    18                     35
# 395   56             8.0                    27                     55
#
#      light_sleep_percentage  awakenings  caffeine_consumption  \
# 229                      20         4.0                  0.00
# 363                      13         0.0                 25.00
# 215                      12         4.0                  1.17
# 211                      47         3.0                  0.00
# 395                      18         2.0                  0.00
#
#      alcohol_consumption  exercise_frequency  month  bedtime_hours_float  \
# 229                 0.00                 3.0      3                 22.5
# ...

# %%
model_LR=LinearRegression()    # model
model_LR.fit(X_train, y_train)   # model train
# Out:
# LinearRegression()

# %%
model_LR.coef_
# Out:
# array([ 0.00107489,  0.00255933,  0.00209509,  0.00187439, -0.00396947,
#        -0.03315101,  0.00017155, -0.00357035,  0.00611288,  0.00039979,
#        -0.0001785 , -0.00090251, -0.00221496, -0.04501322])

# %%
model_LR.intercept_
# Out:
# 0.7399209337475456

# %%
y_pred = pd.DataFrame(model_LR.predict(X_test),columns = ['sleep_efficiency'] )      # model prediction
y_pred_train =  pd.DataFrame(model_LR.predict(X_train),columns = ['sleep_efficiency'])

# %%
print(mse(y_test,y_pred))
print(mae(y_test,y_pred))
##prediction on the train set
print(mse(y_train,y_pred_train))
# Out:
# 0.004058593914299308
# 0.05301266309282716
# 0.0034558058500769465

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.7728938639909675

# %%
R2_test=model_LR.score(X_test,y_test)
R2_train=model_LR.score(X_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
Adj_R2
# Out:
# 0.7466171209816579

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance':(model_LR.coef_.reshape(len(X_train.columns),)) # To check only absolute values: 'Importance':abs (model_LR.coef_.reshape(len(X_train_scaled.columns),))
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)
features_importances
# Out:
#                  Attribute  Importance
# 8       exercise_frequency    0.006113
# 1           sleep duration    0.002559
# 2     rem_sleep_percentage    0.002095
# 3    deep_sleep_percentage    0.001874
# 0                      age    0.001075
# 9                    month    0.000400
# 6     caffeine_consumption    0.000172
# 10     bedtime_hours_float   -0.000178
# 11  wakeuptime_hours_float   -0.000903
# 12             gender_Male   -0.002215
# 7      alcohol_consumption   -0.003570
# 4   light_sleep_percentage   -0.003969
# 5               awakenings   -0.033151
# 13      smoking_status_Yes   -0.045013

# %%
plt.bar(x=features_importances['Attribute'].iloc[:15], height=features_importances['Importance'].iloc[:15], color='#087E8B')
plt.title('Feature importance rankings', size=12)
plt.xticks(rotation='vertical')
plt.show()

# %%
X_train_const = sm.add_constant(X_train.to_numpy()) # adding a constant

model_OLS1 = sm.OLS(y_train, X_train_const).fit()
predictions_train = model_OLS1.predict(X_train_const)

X_test_const = sm.add_constant(X_test) # adding a constant
predictions_test = model_OLS1.predict(X_test_const)
print_model = model_OLS1.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       sleep_efficiency   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     100.3
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          3.20e-101
# Time:                        16:05:46   Log-Likelihood:                 447.11
# No. Observations:                 316   AIC:                            -866.2
# Df Residuals:                     302   BIC:                            -813.6
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002   1.09e-05     20.368      0.000       0.000       0.000
# ...

# %%
y_test = pd.DataFrame(y_test)
y_test = y_test.reset_index(drop = True)

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred,y_pred.to_numpy()-y_test.to_numpy(),"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred,np.zeros(len(y_pred)),linestyle='dashed')

# %%
yp_ = y_pred.to_numpy()
yt_ = y_test.to_numpy()
sns.regplot(yp_,yt_,scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Runing Model with Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled)
X_train_scaled
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1.031986 -0.522649  0.396900  0.196792 -0.297578  1.771442 -0.730048
# 1   -0.735052  2.882651 -0.149594  0.767889 -0.755009 -1.246379  0.105998
# 2   -1.328920 -0.522649  1.489890  0.450613 -0.820356  1.771442 -0.690921
# 3   -2.219721 -0.522649 -1.242584 -1.135768  1.466798  1.016987 -0.730048
# 4    1.195018  0.612451  1.216642  0.133336 -0.428273  0.262531 -0.730048
# ..        ...       ...       ...       ...       ...       ...       ...
# 311  0.972317  0.044901 -1.242584  0.767889 -0.493620 -0.009073  1.778089
# 312 -0.289651  1.180001 -0.696089  0.767889 -0.624315 -0.491924  0.105998
# 313 -0.957753 -1.657749  0.670148  0.640978 -0.820356 -1.246379  1.778089
# 314  0.601150 -0.522649 -0.149594  0.323702 -0.297578 -0.491924 -0.730048
# 315  0.304216 -0.522649 -0.696089 -1.135768  1.336103  1.771442 -0.730048
#
#            7         8         9         10        11   12        13
# ...

# %%
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled)
X_test_scaled
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.749617  0.612451 -1.242584 -1.008858  1.336103 -0.491924 -0.730048
# 1    0.972317 -0.522649  0.396900  0.450613 -0.558967 -0.491924  1.778089
# 2    0.007282  0.612451 -0.149594  0.260247 -0.232231  1.771442  0.105998
# 3   -1.254686 -0.522649 -0.696089 -1.135768  1.336103 -0.491924  0.942044
# 4   -0.809286 -0.522649 -0.149594  0.260247 -0.232231 -0.491924  0.105998
# ..        ...       ...       ...       ...       ...       ...       ...
# 131 -1.031986 -0.522649  0.123653 -1.897231  1.924229  1.016987 -0.730048
# 132 -0.957753 -0.522649 -0.149594  0.260247 -0.232231 -1.246379  0.105998
# 133  0.081516  0.612451 -0.696089  1.085165 -0.951051 -1.246379 -0.730048
# 134 -0.883519 -0.522649  0.123653  0.450613 -0.493620 -0.491924  0.942044
# 135  0.823850  0.612451 -0.696089  0.577523 -0.428273 -1.246379 -0.730048
#
#            7         8         9         10        11   12        13
# ...

# %%
model_LR2=LinearRegression()    # model
model_LR2.fit(X_train_scaled, y_train)   # model train
# Out:
# LinearRegression()

# %%
model_LR2.coef_
# Out:
# array([ 1.45538346e-02,  1.75650545e-03,  1.20373660e+12,  5.18346209e+12,
#         5.03338294e+12, -4.52807996e-02,  4.52868085e-03, -5.11279491e-03,
#         8.02288934e-03,  7.90224166e-04, -1.08631285e-04, -1.35704741e-03,
#        -1.93144555e-03, -2.00713282e-02])

# %%
model_LR2.intercept_
# Out:
# 0.785744938549547

# %%
y_pred2 = pd.DataFrame(model_LR2.predict(X_test_scaled),columns = ['sleep_efficiency'] )      # model prediction
y_pred_train2 =  pd.DataFrame(model_LR2.predict(X_train_scaled),columns = ['sleep_efficiency'])

# %%
print(mse(y_test,y_pred2))
print(mae(y_test,y_pred2))
##prediction on the train set
print(mse(y_train,y_pred_train2))
# Out:
# 0.004033967077449131
# 0.05246518020107545
# 0.0034654191343938792

# %%
R2=r2_score(y_test,y_pred2)
R2
# Out:
# 0.7742719042377297

# %%
R2_test2=model_LR2.score(X_test_scaled,y_test)
R2_train2=model_LR2.score(X_train_scaled,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test_scaled.shape[1]-1)
Adj_R2
# Out:
# 0.7481546039015994

# %%
features_importances2 = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance':(model_LR2.coef_.reshape(len(X_train_scaled.columns),)) # To check only absolute values: 'Importance':abs (model_LR.coef_.reshape(len(X_train_scaled.columns),))
})
features_importances2 = features_importances2.sort_values(by='Importance', ascending=False)
features_importances2
# Out:
#                  Attribute    Importance
# 3    deep_sleep_percentage  5.183462e+12
# 4   light_sleep_percentage  5.033383e+12
# 2     rem_sleep_percentage  1.203737e+12
# 0                      age  1.455383e-02
# 8       exercise_frequency  8.022889e-03
# 6     caffeine_consumption  4.528681e-03
# 1           sleep duration  1.756505e-03
# 9                    month  7.902242e-04
# 10     bedtime_hours_float -1.086313e-04
# 11  wakeuptime_hours_float -1.357047e-03
# 12             gender_Male -1.931446e-03
# 7      alcohol_consumption -5.112795e-03
# 13      smoking_status_Yes -2.007133e-02
# 5               awakenings -4.528080e-02

# %%
plt.bar(x=features_importances2['Attribute'].iloc[:], height=features_importances2['Importance'].iloc[:], color='#087E8B')
plt.title('Feature importance rankings', size=12)
plt.xticks(rotation='vertical')
plt.show()

# %%
fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred2, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred2")
ax[0].set_title("Test Set -Predicted vs real")

ax[1].hist(y_test - y_pred2)
ax[1].set_xlabel("Test y-y_pred2")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred2,y_pred2.to_numpy()-y_test.to_numpy(),"o")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred2,np.zeros(len(y_pred2)),linestyle='dashed')

# %% [markdown]
# ### Runing Model with MinMax Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %%
X_train_minmax = minmax.fit_transform(X_train)
X_train_minmax = pd.DataFrame(X_train_minmax)
X_train_minmax
# Out:
#            0    1         2         3         4     5        6      7    8   \
# 0    0.283333  0.4  0.600000  0.666667  0.232143  1.00  0.00000  0.000  0.6
# 1    0.350000  1.0  0.466667  0.824561  0.107143  0.00  0.12500  0.200  0.0
# 2    0.216667  0.4  0.866667  0.736842  0.089286  1.00  0.00585  1.000  0.2
# 3    0.016667  0.4  0.200000  0.298246  0.714286  0.75  0.00000  0.000  0.0
# 4    0.783333  0.6  0.800000  0.649123  0.196429  0.50  0.00000  0.234  0.6
# ..        ...  ...       ...       ...       ...   ...      ...    ...  ...
# 311  0.733333  0.5  0.200000  0.824561  0.178571  0.41  0.37500  0.000  0.4
# 312  0.450000  0.7  0.333333  0.824561  0.142857  0.25  0.12500  0.200  0.0
# 313  0.300000  0.2  0.666667  0.789474  0.089286  0.00  0.37500  0.000  0.4
# 314  0.650000  0.4  0.466667  0.701754  0.232143  0.25  0.00000  0.000  0.0
# 315  0.583333  0.4  0.333333  0.298246  0.678571  1.00  0.00000  0.600  0.6
#
#            9         10        11   12   13
# ...

# %%
X_test_minmax = minmax.transform(X_test)
X_test_minmax = pd.DataFrame(X_test_minmax)
X_test_minmax
# Out:
#            0    1         2         3         4     5      6    7    8   \
# 0    0.683333  0.6  0.200000  0.333333  0.678571  0.25  0.000  0.4  0.6
# 1    0.733333  0.4  0.600000  0.736842  0.160714  0.25  0.375  0.0  0.4
# 2    0.516667  0.6  0.466667  0.684211  0.250000  1.00  0.125  0.0  0.6
# 3    0.233333  0.4  0.333333  0.298246  0.678571  0.25  0.250  1.0  0.2
# 4    0.333333  0.4  0.466667  0.684211  0.250000  0.25  0.125  0.0  0.4
# ..        ...  ...       ...       ...       ...   ...    ...  ...  ...
# 131  0.283333  0.4  0.533333  0.087719  0.839286  0.75  0.000  0.8  0.0
# 132  0.300000  0.4  0.466667  0.684211  0.250000  0.00  0.125  0.0  0.4
# 133  0.533333  0.6  0.333333  0.912281  0.053571  0.00  0.000  0.0  0.6
# 134  0.316667  0.4  0.533333  0.736842  0.178571  0.25  0.250  0.0  0.2
# 135  0.700000  0.6  0.333333  0.771930  0.196429  0.00  0.000  0.0  0.8
#
#            9         10        11   12   13
# 0    0.909091  0.956522  0.315789  1.0  1.0
# ...

# %%
model_LR3=LinearRegression()    # model
model_LR3.fit(X_train_minmax, y_train)   # model train
# Out:
# LinearRegression()

# %%
model_LR3.coef_
# Out:
# array([ 0.06449325,  0.01279666,  0.04478557,  0.15760536, -0.17241587,
#        -0.13260405,  0.03431047, -0.01785175,  0.03056442,  0.00439768,
#        -0.00410546, -0.00857386, -0.00221496, -0.04501322])

# %%
model_LR3.intercept_
# Out:
# 0.7440256684464842

# %%
y_pred3 = pd.DataFrame(model_LR3.predict(X_test_minmax),columns = ['sleep_efficiency'] )      # model prediction
y_pred_train3 =  pd.DataFrame(model_LR3.predict(X_train_minmax),columns = ['sleep_efficiency'])

# %%
print(mse(y_test,y_pred3))
print(mae(y_test,y_pred3))
##prediction on the train set
print(mse(y_train,y_pred_train3))
# Out:
# 0.004058593914299311
# 0.05301266309282718
# 0.0034558058500769465

# %%
R2=r2_score(y_test,y_pred3)
R2
# Out:
# 0.7728938639909674

# %%
R2_test3=model_LR3.score(X_test_minmax,y_test)
R2_train3=model_LR3.score(X_train_minmax,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test_minmax.shape[1]-1)
Adj_R2
# Out:
# 0.7466171209816579

# %%
features_importances3 = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance':(model_LR2.coef_.reshape(len(X_train_minmax.columns),)) # To check only absolute values: 'Importance':abs (model_LR.coef_.reshape(len(X_train_scaled.columns),))
})
features_importances3 = features_importances3.sort_values(by='Importance', ascending=False)
features_importances3
# Out:
#                  Attribute    Importance
# 3    deep_sleep_percentage  5.183462e+12
# 4   light_sleep_percentage  5.033383e+12
# 2     rem_sleep_percentage  1.203737e+12
# 0                      age  1.455383e-02
# 8       exercise_frequency  8.022889e-03
# 6     caffeine_consumption  4.528681e-03
# 1           sleep duration  1.756505e-03
# 9                    month  7.902242e-04
# 10     bedtime_hours_float -1.086313e-04
# 11  wakeuptime_hours_float -1.357047e-03
# 12             gender_Male -1.931446e-03
# 7      alcohol_consumption -5.112795e-03
# 13      smoking_status_Yes -2.007133e-02
# 5               awakenings -4.528080e-02

# %%
plt.bar(x=features_importances3['Attribute'].iloc[:], height=features_importances3['Importance'].iloc[:], color='#087E8B')
plt.title('Feature importance rankings', size=12)
plt.xticks(rotation='vertical')
plt.show()
